# %%
import pandas as pd

# %%
violation_df = pd.read_csv('Data/Property_Standards_Violations_2_Cleaned.csv')
pd.set_option('display.max_columns', None)
# Out:
# /var/folders/5y/6gtz4tzx39g7849gcdbdht800000gp/T/ipykernel_99569/2744169512.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   violation_df = pd.read_csv('Data/Property_Standards_Violations_2_Cleaned.csv')

# %%
permits_df = pd.read_csv('Data/Building_Permits_Issued_Cleaned.csv')
pd.set_option('display.max_columns', None)

# %%
violation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42716 entries, 0 to 42715
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   object_id            42716 non-null  int64
#  1   request_#            42716 non-null  object
#  2   date_received        42716 non-null  object
#  3   property_apn         42716 non-null  object
#  4   property_address     42716 non-null  object
#  5   city                 42713 non-null  object
#  6   state                42716 non-null  object
#  7   property_owner       42716 non-null  object
#  8   complaint_source     42716 non-null  object
#  9   reported_problem     42716 non-null  object
#  10  status               42716 non-null  object
#  11  cncl_dist            42716 non-null  int64
#  12  last_activity_date   42709 non-null  object
#  13  Last_Activity        42709 non-null  object
#  14  last_act__result     42709 non-null  object
# ...

# %%
permits_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28622 entries, 0 to 28621
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Permit_#                    28622 non-null  object
#  1   Permit_type_description     28622 non-null  object
#  2   Permit_subtype_description  28622 non-null  object
#  3   Parcel                      28622 non-null  object
#  4   Date_entered                28622 non-null  object
#  5   Date_issued                 28622 non-null  object
#  6   Construction_cost           28622 non-null  int64
#  7   Address                     28622 non-null  object
#  8   City                        28620 non-null  object
#  9   State                       28622 non-null  object
#  10  Subdivision_lot             28622 non-null  object
#  11  Contact                     28621 non-null  object
#  12  Permit_type                 28622 non-null  object
# ...

# %%
permits_df.head(25)
# Out:
#        Permit_#                  Permit_type_description  \
# 0    2020037584              Building Commercial - Rehab
# 1    2020062603                 Building Use & Occupancy
# 2    2020077789                Building Commercial - New
# 3    2021020545                Building Commercial - New
# 4    2021023674                Building Commercial - New
# 5   T2021027879               Building Residential - New
# 6    2021035334               Building Residential - New
# 7    2021036500               Building Demolition Permit
# 8    2021037636  Building Commercial - Tenant Finish Out
# 9    2021038553  Building Commercial - Tenant Finish Out
# 10   2021038554  Building Commercial - Tenant Finish Out
# 11   2021043334                     Building Sign Permit
# 12   2021047790               Building Residential - New
# 13   2021049445                Building Commercial - New
# 14   2021056442                 Building Use & Occupancy
# ...

# %%
violation_df.head()
# Out:
#    object_id   request_# date_received property_apn        property_address  \
# 0      34755  26-1464307     2/10/2026    200001400         133 EAST END RD
# 1      27518  25-1444564     7/29/2025    300004400          2443 TINNIN RD
# 2      10827  24-1392290      6/7/2024    400000700  8414 WHITES CREEK PIKE
# 3      11011  24-1392887     6/11/2024    400000700  8414 WHITES CREEK PIKE
# 4      34006  25-1458100     12/2/2025    400000800  8480 WHITES CREEK PIKE
#
#              city state                       property_owner  \
# 0  GOODLETTSVILLE    TN            DOWLEN, AUDREY ANN & MARK
# 1  GOODLETTSVILLE    TN                 BRATTEN, SANDRA BYRD
# 2         JOELTON    TN  HUGHES, SANDRA & PORTER, ROBERT LEE
# 3         JOELTON    TN  HUGHES, SANDRA & PORTER, ROBERT LEE
# 4         JOELTON    TN                        LARES, MIGUEL
#
#      complaint_source                                   reported_problem  \
# ...

# %%
permits_df.isna().sum()
# Out:
# Permit_#                       0
# Permit_type_description        0
# Permit_subtype_description     0
# Parcel                         0
# Date_entered                   0
# Date_issued                    0
# Construction_cost              0
# Address                        0
# City                           2
# State                          0
# Subdivision_lot                0
# Contact                        1
# Permit_type                    0
# Permit_sub_type                0
# Purpose                        0
# Council_district              15
# Census_tract                   0
# Longitude                      0
# Latitude                       0
# ObjectId                       0
# Zipcode                        0
# x                              0
# y                              0
# dtype: int64

# %%
violation_df.isna().sum()
# Out:
# object_id               0
# request_#               0
# date_received           0
# property_apn            0
# property_address        0
# city                    3
# state                   0
# property_owner          0
# complaint_source        0
# reported_problem        0
# status                  0
# cncl_dist               0
# last_activity_date      7
# Last_Activity           7
# last_act__result        7
# violations_noted       49
# longitude               0
# latitude                0
# zipcode                 0
# subtype_description     0
# x                       0
# y                       0
# dtype: int64

# %%
permits_df['Permit_type_description'].value_counts()
# Out:
# Permit_type_description
# Building Residential - New                  10326
# Building Commercial - Rehab                  3755
# Building Residential - Addition              3124
# Building Residential - Rehab                 2352
# Building Sign Permit                         2157
# Building Demolition Permit                   2153
# Building Commercial - Tenant Finish Out      1257
# Building Commercial - New                     849
# Building Residential - Change Contractor      413
# Building Use & Occupancy                      393
# Building Tree Removal Permit                  347
# Building Commercial - Roofing / Siding        346
# Building Commercial - Addition                252
# Building Commercial - Change Contractor       182
# Building Residential - Roofing / Siding       166
# Building Commercial - Shell                   136
# Building Commercial - Amend Permit            100
# Building Residential - Amend Permit            67
# ...

# %%
violation_df['subtype_description'].value_counts()
# Out:
# subtype_description
# Codes Housing Request                   27206
# Codes High Grass and Weeds               7923
# PS Audit                                 3803
# Short Term Rental Property               1519
# CA Codes Case                             893
# Codes Sign Request                        697
# Home Occupation PS Complaint              289
# Codes Right of Way Request                156
# CA Paid Parking Lot                       114
# CA PS Night Inspection                     48
# Codes Neighborhood Request                 19
# Codes Urban Forestry                       16
# Landlord Registration Violation            16
# CA Paid Parking Garage                      6
# PS - Sign Removal                           6
# Codes Building Division                     3
# Health Department General Sanitation        1
# Codes Vacant Lot High Grass                 1
# Name: count, dtype: int64

# %%
permits_df.head()
# Out:
#      Permit_#      Permit_type_description  \
# 0  2020037584  Building Commercial - Rehab
# 1  2020062603     Building Use & Occupancy
# 2  2020077789    Building Commercial - New
# 3  2021020545    Building Commercial - New
# 4  2021023674    Building Commercial - New
#
#                 Permit_subtype_description       Parcel Date_entered  \
# 0  Day Care Center (Up To 75) - Child Care   5106006200    6/17/2020
# 1                    Multifamily, Townhome   4315005700    10/5/2020
# 2                    Restaurant (Take Out)   7102009200   12/14/2020
# 3   Community Education, Indr Tennis Court  13114010000     4/6/2021
# 4            Leasing / Sales Office, Other  16400033500    4/18/2021
#
#   Date_issued  Construction_cost                  Address       City State  \
# 0    4/9/2024              82455     1022 S GRAYCROFT AVE    MADISON    TN
# 1   7/24/2023                  1   910 OLD HICKORY BLVD E    MADISON    TN
# ...

# %%
resi_df = permits_df[permits_df['Permit_type_description'].str.contains('Residential', case=False, na=False)]
resi_df.head(10)
# Out:
#        Permit_#          Permit_type_description  \
# 5   T2021027879       Building Residential - New
# 6    2021035334       Building Residential - New
# 12   2021047790       Building Residential - New
# 18   2021065100       Building Residential - New
# 19   2021068296       Building Residential - New
# 26   2021080120  Building Residential - Addition
# 27   2021081541       Building Residential - New
# 28   2022002416       Building Residential - New
# 29   2022005717       Building Residential - New
# 31   2022008466       Building Residential - New
#
#                   Permit_subtype_description          Parcel Date_entered  \
# 5   Accessory Structure, Pools - Residential     13004001000     5/4/2021
# 6                    Single Family Residence  160080C00700CO     6/6/2021
# 12          Detached Accessory Dwelling Unit     11704025400    7/28/2021
# 18                   Single Family Residence  160080C00500CO   10/11/2021
# ...

# %%
com_df = permits_df[permits_df['Permit_type_description'].str.contains('Commercial', case=False, na=False)]
com_df.head(10)
# Out:
#       Permit_#                  Permit_type_description  \
# 0   2020037584              Building Commercial - Rehab
# 2   2020077789                Building Commercial - New
# 3   2021020545                Building Commercial - New
# 4   2021023674                Building Commercial - New
# 8   2021037636  Building Commercial - Tenant Finish Out
# 9   2021038553  Building Commercial - Tenant Finish Out
# 10  2021038554  Building Commercial - Tenant Finish Out
# 13  2021049445                Building Commercial - New
# 16  2021061942              Building Commercial - Shell
# 17  2021063222                Building Commercial - New
#
#                   Permit_subtype_description          Parcel Date_entered  \
# 0    Day Care Center (Up To 75) - Child Care      5106006200    6/17/2020
# 2                      Restaurant (Take Out)      7102009200   12/14/2020
# 3     Community Education, Indr Tennis Court     13114010000     4/6/2021
# ...

# %%
res_df = permits_df[permits_df['Permit_type_description'].str.contains('Residential', case=False, na=False)]
res_df.head(10)
